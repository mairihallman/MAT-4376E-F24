# %%
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import pairwise_distances
import matplotlib.pyplot as plt
from joblib import parallel_backend

# %%
df = pd.read_csv('data-p4/Flights1_2019_1.csv')
# Out:
#         YEAR  DAY_OF_WEEK     FL_DATE  ORIGIN_AIRPORT_ID  \
# 0       2019            6  2019-01-19              13487
# 1       2019            7  2019-01-20              13487
# 2       2019            1  2019-01-21              13487
# 3       2019            2  2019-01-22              13487
# 4       2019            3  2019-01-23              13487
# ...      ...          ...         ...                ...
# 583980  2019            3  2019-01-30              14057
# 583981  2019            3  2019-01-30              13930
# 583982  2019            3  2019-01-30              14635
# 583983  2019            3  2019-01-30              11618
# 583984  2019            3  2019-01-30              14107
#
#         ORIGIN_AIRPORT_SEQ_ID  ORIGIN_CITY_MARKET_ID ORIGIN_CITY_NAME  \
# 0                     1348702                  31650  Minneapolis, MN
# 1                     1348702                  31650  Minneapolis, MN
# 2                     1348702                  31650  Minneapolis, MN
# 3                     1348702                  31650  Minneapolis, MN
# 4                     1348702                  31650  Minneapolis, MN
# ...                       ...                    ...              ...
# 583980                1405702                  34057     Portland, OR
# 583981                1393007                  30977      Chicago, IL
# 583982                1463502                  31714   Fort Myers, FL
# 583983                1161802                  31703       Newark, NJ
# 583984                1410702                  30466      Phoenix, AZ
#
#         DEST_AIRPORT_ID  DEST_AIRPORT_SEQ_ID  DEST_CITY_MARKET_ID  \
# 0                 11193              1119302                33105
# 1                 11193              1119302                33105
# 2                 11193              1119302                33105
# 3                 11193              1119302                33105
# 4                 11193              1119302                33105
# ...                 ...                  ...                  ...
# 583980            13930              1393007                30977
# 583981            14908              1490803                32575
# 583982            13930              1393007                30977
# 583983            13930              1393007                30977
# 583984            13930              1393007                30977
#
#         DEST_CITY_NAME DEST_STATE_ABR  DEP_DELAY  ARR_TIME  ARR_DELAY  \
# 0       Cincinnati, OH             KY      -10.0    1832.0      -25.0
# 1       Cincinnati, OH             KY       -4.0    1825.0      -37.0
# 2       Cincinnati, OH             KY       -9.0    1845.0      -17.0
# 3       Cincinnati, OH             KY       -4.0    1839.0      -23.0
# 4       Cincinnati, OH             KY       -6.0    1850.0      -12.0
# ...                ...            ...        ...       ...        ...
# 583980     Chicago, IL             IL       -9.0    1225.0      -27.0
# 583981   Santa Ana, CA             CA       35.0    2230.0       17.0
# 583982     Chicago, IL             IL      132.0    2035.0      113.0
# 583983     Chicago, IL             IL       32.0     841.0       37.0
# 583984     Chicago, IL             IL        NaN       NaN        NaN
#
#         ARR_DELAY_NEW  ARR_DEL15  Unnamed: 17
# 0                 0.0        0.0          NaN
# 1                 0.0        0.0          NaN
# 2                 0.0        0.0          NaN
# 3                 0.0        0.0          NaN
# 4                 0.0        0.0          NaN
# ...               ...        ...          ...
# 583980            0.0        0.0          NaN
# 583981           17.0        1.0          NaN
# 583982          113.0        1.0          NaN
# 583983           37.0        1.0          NaN
# 583984            NaN        NaN          NaN
#
# [583985 rows x 18 columns]

# %%
df.dropna(subset=['DEP_DELAY','ARR_DELAY'],inplace=True)

df['DEP_DELAY_scaled'] = 2 * (df['DEP_DELAY'] - df['DEP_DELAY'].min()) / \
                        (df['DEP_DELAY'].max() - df['DEP_DELAY'].min()) - 1
df['ARR_DELAY_scaled'] = 2 * (df['ARR_DELAY'] - df['ARR_DELAY'].min()) / \
                        (df['ARR_DELAY'].max() - df['ARR_DELAY'].min()) - 1

# %%
vals = df[['DEP_DELAY_scaled','ARR_DELAY_scaled']].values.astype(np.float32)

# %%
batch_size = 25000  # can adjust based on available RAM
n = vals.shape[0]
distances = np.zeros((n, n))

# %%
for i in range(0, n, batch_size):
    for j in range(0, n, batch_size):
        print(f"Processing block ({i}:{i+batch_size}, {j}:{j+batch_size})...")
        
        with parallel_backend('threading', n_jobs=-1):
            distances = pairwise_distances(
                vals[i:i+batch_size],
                vals[j:j+batch_size],
                metric='euclidean'
            ).astype(np.float32)
        np.save(f"data-p4/pairwise_distances/distances_{i}_{j}.npy", distances) # change to your path
# Out:
# Processing block (0:25000, 0:25000)...
# Processing block (0:25000, 25000:50000)...
# Processing block (0:25000, 50000:75000)...
# Processing block (0:25000, 75000:100000)...
# Processing block (0:25000, 100000:125000)...
# Processing block (0:25000, 125000:150000)...
# Processing block (0:25000, 150000:175000)...
# Processing block (0:25000, 175000:200000)...
# Processing block (0:25000, 200000:225000)...
# Processing block (0:25000, 225000:250000)...
# Processing block (0:25000, 250000:275000)...
# Processing block (0:25000, 275000:300000)...
# Processing block (0:25000, 300000:325000)...
# Processing block (0:25000, 325000:350000)...
# Processing block (0:25000, 350000:375000)...
# Processing block (0:25000, 375000:400000)...
# Processing block (0:25000, 400000:425000)...
# Processing block (0:25000, 425000:450000)...
# Processing block (0:25000, 450000:475000)...
# Processing block (0:25000, 475000:500000)...
# Processing block (0:25000, 500000:525000)...
# Processing block (0:25000, 525000:550000)...
# Processing block (0:25000, 550000:575000)...
# Processing block (25000:50000, 0:25000)...
# Processing block (25000:50000, 25000:50000)...
# Processing block (25000:50000, 50000:75000)...
# Processing block (25000:50000, 75000:100000)...
# Processing block (25000:50000, 100000:125000)...
# Processing block (25000:50000, 125000:150000)...
# Processing block (25000:50000, 150000:175000)...
# Processing block (25000:50000, 175000:200000)...
# Processing block (25000:50000, 200000:225000)...
# Processing block (25000:50000, 225000:250000)...
# Processing block (25000:50000, 250000:275000)...
# Processing block (25000:50000, 275000:300000)...
# Processing block (25000:50000, 300000:325000)...
# Processing block (25000:50000, 325000:350000)...
# Processing block (25000:50000, 350000:375000)...
# Processing block (25000:50000, 375000:400000)...
# Processing block (25000:50000, 400000:425000)...
# Processing block (25000:50000, 425000:450000)...
# Processing block (25000:50000, 450000:475000)...
# Processing block (25000:50000, 475000:500000)...
# Processing block (25000:50000, 500000:525000)...
# Processing block (25000:50000, 525000:550000)...
# Processing block (25000:50000, 550000:575000)...
# Processing block (50000:75000, 0:25000)...
# Processing block (50000:75000, 25000:50000)...
# Processing block (50000:75000, 50000:75000)...
# Processing block (50000:75000, 75000:100000)...
# Processing block (50000:75000, 100000:125000)...
# Processing block (50000:75000, 125000:150000)...
# Processing block (50000:75000, 150000:175000)...
# Processing block (50000:75000, 175000:200000)...
# Processing block (50000:75000, 200000:225000)...
# Processing block (50000:75000, 225000:250000)...
# Processing block (50000:75000, 250000:275000)...
# Processing block (50000:75000, 275000:300000)...
# Processing block (50000:75000, 300000:325000)...
# Processing block (50000:75000, 325000:350000)...
# Processing block (50000:75000, 350000:375000)...
# Processing block (50000:75000, 375000:400000)...
# Processing block (50000:75000, 400000:425000)...
# Processing block (50000:75000, 425000:450000)...
# Processing block (50000:75000, 450000:475000)...
# Processing block (50000:75000, 475000:500000)...

# %%
df['dtap'] = distances.sum(axis=1)

# %%
plt.scatter(df.index, df['dtap'])
plt.title("Distance to All Points")
plt.xlabel("Index")
plt.ylabel("DTAP")
plt.show()

# %%
df['dtap'].nlargest(10).index # show top 10 points with highest dtap

# %%
np.fill_diagonal(distances, np.inf)
df['dtnn'] = np.min(distances, axis=1)

# %%
plt.scatter(df.index, df['dtnn'])
plt.title("Distance to Nearest Neighbour")
plt.xlabel("Index")
plt.ylabel("DTNN")
plt.show()

# %%
df['dtnn'].nlargest(10).index # show top 10 points with highest dtnn
